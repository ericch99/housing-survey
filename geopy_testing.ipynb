# %%
import numpy as np
import pandas as pd
import re
import json
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib.mlab as mlab
import geopy

# %%
df = pd.read_json('./data/cragslist.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-695dda940d7f> in <module>
# ----> 1 df = pd.read_json('./data/cragslist.json')
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     527             )
#     528         else:
# --> 529             obj = self._get_object_parser(self.data)
#     530         self.close()
#     531         return obj
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in _get_object_parser(self, json)
# ...

# %%
df.head()
# Out:
#                                        address   price  bed  bath    area  \
# 0                            2709 N Spurway Dr  3300.0    3   2.5  2438.0
# 1                             1777 Plymouth Rd  1625.0    1   1.0   730.0
# 10                        City Place Ann Arbor   975.0    6   6.0  2665.0
# 100   5 br, 2 bath House - 504 Lawrence St # 2  4000.0    5   2.0     NaN
# 1000                                The George  2619.0    2   2.0  1225.0
#
#                          company  neighborhood  laundry  pets  parking  \
# 0                           None           NaN        0     0        0
# 1                           None           NaN        0     0        0
# 10    Campus Village Communities           NaN        1     0        0
# 100                         None           NaN        1     1        0
# 1000          The Hayman Company           NaN        1     0        0
#
#      utilities property_type  year_built  \
# 0           []     apartment         NaN
# ...
